# %% [markdown]
# # Cyclic Voltammetry Simulation for CHEM 577 Final
# This simulation produces model voltammograms using a relatively simple set of parameters. It uses both diffusion and kinetic based changes in the concentrations and flux of a model system to produce a flux difference and as such a current that can be plotted against an overpotential like in an experimental CV. A full pdf write up will be provided with submission of this simulation.

# %% [markdown]
# ## Package imports

# %%
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simulation Inputs
# We begin by declaring all of the essential parameters to run the simulation. These can be changed quite easily to reflect changes in the system.

# %%
# Constants
T = 298 # Temperature [K]
F = 96485 # Faraday’s constant [C/mol]
R = 8.3145 # Gas constant [(C*V)/(mol*K)]
f = F/(R*T) # Reduced electrochemical parameter
Cox = 1.0 #  initial concentration of Ox [M]
D = 1E-6 # Diffusion coefficient [cm^2/s] {default: 1E-6}
v = 80*1E-3 # Scan rate [V/s] {default: 1E-3}
n = 1.0  # Number of electrons transferred during reaction {default: 1}
alpha = 0.5  # Transfer coefficient (unitless) {default: 0.5}
kc = 1E-3 # Chemical rate constant [m/s] {default: 1E-3}
A = 1 # Electrode surface area [cm^3] {default: 1}

# Simulation Paramterers 
L = 500 # Number of time steps {default: 500}
DM = 0.45 # Model diffusion coefficient from problem. Default = 0.45
eta0 = 0.8 # Initial overpotential (relative to redox) [V] {default: 0.2}
etaF = -0.8 # Final overpotential (relative to redox) [V] {default: -0.2}

# Time paramaters 
ti = np.array(list(range(0,L))) # time index vector
total_t  = 2*(eta0-etaF)/v # Maximum t value to simulate (1 CV)
del_t  = total_t/L # Time interval
t = del_t * ti # Discretized t
tset1 = t[0:250] # First half of the discretized time

# Kinetic parameters
ktk = kc*total_t   # Dimensionless kinetic parameter 
km = ktk/L # Normalized Dimensionless Kinetic parameter
Lambda = k0/(D*f*v)**(0.5)  # Dimensionless Reversibility Parameter
psi = 0.1 # Dimensionless Reversibility Parameter
k0 = psi * np.sqrt((D*f*v)/np.pi) # Heterogeneous rate constant [m/s] {default: dependent on psi parameter}

# Mesh Point Parameters
del_x  = np.sqrt(D*del_t/DM) # x interval
npts_x = 100  # Number of mesh points {default: 100}

# %% [markdown]
# ## Initial Setup and Time Step
# This section declares some variables and establishes some matrices needed for the simulation to run in the following cell.

# %%
# Concentration units
Cox= Cox / 1000 # Convert C from mol/L to mol/cm3

#O verpotential parameters
eta1 = list(eta0 - v * tset1) # Overpotential vector, negative scan
eta2 = list(reversed(eta1)) # Reverse of previous list to complete second half of overpotential scans
eta = np.asarray(eta1 + eta2) # Overpotential scan values [V] 
Enorm = eta * f # normalized overpotential

kf = k0 *np.exp(-alpha * n * Enorm) # Forward rate constant [cm/s] 
kb = k0 *np.exp((1-alpha) * n * Enorm) # Reverse rate constant [cm/s],  

Cox_x = Cox*np.ones((L+1,npts_x)) # Concentration of Cox_x [mol/cm^3] 
Cred_x = np.zeros((L+1,npts_x))  # Concentration of Cred_x [mol/cm^3] 
Flux = np.zeros((1,L+1)) # Flux of Cox_x at the surface mol/cm^2-s,

# %% [markdown]
# ## Simulation
# This section runs the actual simualation that allows for the prediction of a current. A full description of this method is given in the submitted pdf.

# %%
# Run Simulation
# j = time index. i = distance index
for j in range (1,L-1):
    # Update bulk concentrations of Cox_x and Cred_x
    for i in range(1,npts_x-1):
        Cox_x[j+1,i] = Cox_x[j,i] + DM*(Cox_x[j,i+1]+Cox_x[j,i-1]-2*Cox_x[j,i])
        Cred_x[j+1,i] = Cred_x[j,i] + DM*(Cred_x[j,i+1]+Cred_x[j,i-1]-2*Cred_x[j,i]) - km * Cred_x[j,i]

    # Update Flux
    if j == L:
        Flux[j] = Flux[j-1]
    else:
        Flux[0,j+1] = (kf[j+1] * Cox_x[j+1,1] - kb[j+1] * Cred_x[j+1,1]) / (1 + del_x/D*(kf[j+1] + kb[j+1]))

    # Update surface concentrations
    Cox_x[j+1,0] = Cox_x[j+1,2] - Flux[0,j+1]*(del_x/D)
    Cred_x[j+1,0] = Cred_x[j+1,2] + Flux[0,j+1]*(del_x/D) - km*Cred_x[j+1,1]

# Calculate current density, Z, from flux of Cox_x
Z3 = -n *F * Flux * A *1000 # [=] A/cm^2 -> mA/cm^2, current density

#Derivation of E_pp
inminvolt = np.argmin(Z[0]) # Finding the index of the min current value
inmaxvolt = np.argmax(Z[0]) # Finding the index of the max current value
Epp = eta[inmaxvolt] - eta[inminvolt] # Derivation of E_pp

# %% [markdown]
# ## Plotting
# Plotting various figures needed for the pdf report.

# %%
fig = plt.figure(figsize = (6,4))

#Trend 
plt.plot(t,eta, color = 'black')


#Font selection
matplotlib.rcParams['font.serif'] = "Palatino"
matplotlib.rcParams['font.family'] = "serif"

#Plot Labeling
plt.title('Applied Overpotential over Time')
plt.xlabel('Time (s)', fontsize = '12')
plt.ylabel('Overpotential (V)', fontsize = '12')


#SaveFig
plt.savefig('etavt.png', dpi=1200)

# %%
Zlist3 = Z3.flatten()
Znew3 = Zlist3[0:-1]


fig = plt.figure(figsize = (6,4))

#Trend 
plt.plot(eta,Znew, color = 'black')

#Font selection
matplotlib.rcParams['font.serif'] = "Palatino"
matplotlib.rcParams['font.family'] = "serif"

#Plot Labeling
plt.title('Cyclic Voltammetry Simulation')
plt.xlabel('Overpotential (V)', fontsize = '12')
plt.ylabel('Current [mA]', fontsize = '12')

#SaveFig
plt.savefig('DefaultCVFinal.png', dpi=1200)

# %%
fig = plt.figure(figsize = (6,4))

#Trend 
plt.plot(eta,Znew, color = 'black', label = r'$\psi = 20$')
plt.plot(eta,Znew2, color = 'blue', label = r'$\psi = 1$')
plt.plot(eta,Znew3, color = 'purple', label = r'$\psi = 0.1$')


#Font selection
matplotlib.rcParams['font.serif'] = "Palatino"
matplotlib.rcParams['font.family'] = "serif"

#Plot Labeling
plt.title('Effect of Quasireversibility on Voltammogram')
plt.xlabel('Overpotential (V)', fontsize = '12')
plt.ylabel('Current [mA]', fontsize = '12')

#Legend
plt.legend(loc="upper right")


#SaveFig
plt.savefig('DifPsiCVFinal.png', dpi=1200)
